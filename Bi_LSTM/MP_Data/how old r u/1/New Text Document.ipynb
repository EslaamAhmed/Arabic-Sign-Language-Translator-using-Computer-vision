# %%
import numpy as np 
from matplotlib import pyplot as plt
data = np.load('33.npy')
print(data[0:33])
plt.plot(data)
plt.show()
# Out:
# [ 0.50262493  0.30409268 -0.98138845  0.99985456  0.53167856  0.23702869
#  -0.91527951  0.99972785  0.55080038  0.23566316 -0.91538012  0.99973994
#   0.56703806  0.23464912 -0.91500366  0.99971229  0.47747475  0.2396899
#  -0.92476308  0.99971402  0.45985118  0.24056676 -0.92462128  0.99972099
#   0.44339561  0.24159473 -0.9251169   0.99970293  0.58761525  0.25587529
#  -0.44694448  0.99977469  0.42695522]
